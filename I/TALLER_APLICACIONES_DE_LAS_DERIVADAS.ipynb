# %% [markdown]
# <img src=http://www.acofi.edu.co/eiei2016/wp-content/uploads/2016/09/Logo-Universidad-ICESI.jpg width="200" height="200" align="center">
#
# #<big><big>Matemáticas Aplicadas I</big></big><br><small>Depto. Matemáticas & Estadística / Facultad de Ingeniería

# %% [markdown]
# #<font color= 9ACD32> **CUADERNO FINAL - Aplicaciones de las derivadas**
# ---
#
#
# **Integrantes grupo:**
#
# * Mariana Agudelo
# * Juan José De la Pava
# * Rony Farid Ordónez
# ---

# %% [markdown]
# ##<font color= 9ACD32>Optimización
# Con base en los ejemplos y la teoría desarrollada en las secciones anteriore, sugerimos el siguiente método paso a paso que puede aplicarse a muchos problemas prácticos de optimización.
#
# * Paso 1: Haga un dibujo del problema y asigne variables idóneas para las cantidades importantes.
#
# * Paso 2: Escriba una fórmula para la función objetivo Q que se maximizará o minimizará, en términos de las variables del paso 1.
#
# * Paso 3: Utilice las condiciones del problema para eliminar todas, excepto una de estas variables, y por consiguiente expresar a Q como una función de una sola variable.
#
# * Paso 4: Encuentre los puntos críticos (fronterizos, estacionarios, singulares).
#
# * Paso 5: Sustituya los valores críticos en la función objetivo o bien utilice la teoría dela última sección (es decir, los criterios de la primera o segunda derivada) para determinar el máximo o el mínim0.

# %% [markdown]
# Teniendo en cuenta el analisis anterior; resolver los siguientes ejercicios
# 1. Encuentre las dimensiones del cilindro circular recto de volumen
# máximo que puede inscribirse en un cono circular recto dado
#
# 2. Suponga que un pez nada río arriba con velocidad relativa al agua
# $v$ y que la corriente del río tiene velocidad $-v_c$ (el signo negativo indica que la velocidad de la corriente es en dirección opuesta a la del pez). La energía empleada en recorrer una distancia $d$ a contracorriente es directamente proporcional al tiempo requerido para recorrer la distancia $d$ y el cubo de la velocidad. ¿Qué velocidad $v$ minimiza la energía empleada en nadar esta distancia?
#
# 3. Un pasillo de 6 pies de ancho da vuelta en ángulo recto. ¿Cuál es
# la longitud de la varilla delgada más larga que puede transportarse alrededor de la esquina, suponiendo que la varilla no puede doblarse?
#
# 4. Un objeto que se arroja desde el borde de un acantilado de 100 pies, sigue la trayectoria dada por  $ h=\frac{-x^2}{100}+x+100$. Un observador se encuentra parado a 2 pies del fondo del acantilado. (a) Encuentre la posición del objeto cuando está más cerca del observador. (b) Encuentre la posición del objeto cuando está más lejos del observador.

# %% [markdown]
# ###<font color= 9ACD32>1.
#
# ![image.png](data:image/png;base64,...)
#
#
# **Volúmen del cilindro:** → $V=πr^2h$
#
# * Por semejanza de triángulos: $h=\frac{-a}{b} r + a$
#
# *Reemplazamos en la función del volumen del cilindro:*
#
# $$V=πr^2(\frac{-a}{b} r + a)$$
#
# $$V(r)=πr^2a - \frac{a}{b} πr^3$$
#
# *Derivamos:*
#
# $$V'(r)=2πra - \frac{3a}{b} πr^2$$
#
# $$V'(r)=πra (2 - \frac{3}{b}r) = 0\:$$
#
# *(Igualamos a $0$ para encontrar un posible punto máximo.)*
#
# $r=0 →$ NO puede ser solución
#
# $2-\frac{3}{b}r =0$
#
# $\frac{2b}{3} =r$
#
# *(Sacamos la segunda derivada para verificar que sea un punto máximo)*
#
#
# $$V''(r)=2πa - \frac{6a}{b} πr$$
#
# $$V''(\frac{2b}{3})=2πa - \frac{6a}{b} π(\frac{2b}{3}) = 2πa - 4πa$$
#
# $$V''(\frac{2b}{3})= -2πa$$
#
# ⇒ $-2πa < 0$ **Cóncava hacia abajo**
#
# $r = \frac{2b}{3}$ *Es punto máximo*
#
# **$:.$ Las dimensiones del cilindro son:**
#
#
# * $r = \frac{2b}{3}$
#
# * $h= \frac{a}{3}$  *(Al reemplazar r en $h=\frac{-a}{b} r + a$)*

# %% [markdown]
# ###<font color= 9ACD32>2.
#
# ![image.png](data:image/png;base64,...)
#
#
#
# **Energía que emplea el pez:**
# $E=ktv^3$
#
# → La velocidad del pez es relativa $:.  v-v_c$
#
# $t=\frac{d}{v}= \frac{d}{v-v_c}$
#
# $$E(v)=k\frac{d}{v-v_c}v^3$$
#
# *Organizamos la función para derivar solo la variable $v$ ($kd$ Son constantes)*
#
#
# $$E(v)=kd\frac{v^3}{v-v_c}$$
#
# → El dominio de la función es $(v_c, ∞)$ (En este intérvalo se analizarán los puntos críticos)
#
# **Primera derivada para hallar posibles puntos críticos**
#
# $$E'(v)=kd\frac{3v^2(v-v_c) - v^3}{(v-v_c)^2}$$
#
# *Simplificamos*
#
# $$E'(v)=\frac{kd}{(v-v_c)^2} v^2(2v-3v_c)$$
#
# *Igualamos a $0$*
#
# $$0=\frac{kd}{(v-v_c)^2} v^2(2v-3v_c)$$
#
# * Opción 1: $v=0$ NO es posible
#
# * Opción 2: $v^2(2v - 3v_c)=0$ ⇒ $v=\frac{3}{2}v_c$
#
# *Nota:* $\frac{3}{2} = 1.5$
#
# **Análisis:**
#
# ⇒ El signo de $E'(v)$ depende de $(2v - 3v_c)$, dado que si esta expresión toma un valor negativo toda la ecuación también lo hará, en caso de lo opuesto, la ecuación tendrá un valor positivo.
#
# * Cuando $v=1$:
#   $(2v - 3v_c)$ resulta con signo negativo porque $v<\frac{3}{2}v_c$
#   Como la expresión es **menor** a $0$, decimos que decrece.
#
# * Cuando $v=2$:
#   $(2v - 3v_c)$ resulta con signo positivo porque $v>\frac{3}{2}v_c$
#   Como la expresión es **mayor** a $0$, decimos que crece.
#
#
# **Por lo tanto** podemos decir que $v=\frac{3}{2}v_c$ en el intérvalo $(v_c, ∞)$ es un mínimo global.
#
# *Respuesta:* La velocidad que minimiza la energía la energía emplada por el pez es $\frac{3}{2}v_c$ (La mitad de tres veces la rapidez de la corriente)

# %% [markdown]
# ###<font color= 9ACD32>3.
# ![punto3.jpeg](data:image/jpeg;base64,...)
#
# $△ADB$ semejante con $△BFC$
#
# **Longitud:**
#
# $$L=a+b$$
#
# * $△ADB$
#
# $$cosθ=\frac{6}{a}$$
#
# $$a=\frac{6}{cosθ}= 6secθ$$
#
# * $△BFC$
#
# $$senθ=\frac{6}{b}$$
#
# $$a=\frac{6}{senθ}= 6cscθ$$
#
#
# *Dominio para:* $θ ∈ (0, \frac{π}{2})$
#
#
# **Reemplazamos valores para la función de longitud:**
#
# $$L(θ) = 6secθ + 6cscθ$$
#
# **Derivamos:**
#
# $$L'(θ) = 6secθtanθ + 6cscθcotθ$$
#
# *Igualamos a $0$*
#
# $$L'(θ) = 6(\frac{senθ}{cos^2θ} - \frac{cosθ}{sen^2θ})=0$$
#
# $$L'(θ) = 6(\frac{sen^3θ - cos^3θ}{sen^2θ cos^2θ}) =0$$
#
# $$\frac{6}{sen^2θ cos^2θ}(sen^3θ - cos^3θ) =0$$
#
#
# $$(sen^3θ - cos^3θ) = 0$$
#
# $$sen^3θ = cos^3θ$$
#
# $$senθ = cosθ$$
#
# *Importante:* El único ángulo en el intérvalo $(0, \frac{π}{2})$ donde $senθ = cosθ$ es $θ=\frac{π}{4}$
#
# **Análisis:**
#
# * Cuando $0<θ<\frac{π}{4}$:
#   Por ejemplo: $θ=\frac{π}{8}$
#
#   $$sen(\frac{π}{8})=0.382$$
#
#   $$cos(\frac{π}{8})=0.923$$
#
#   *Por lo tanto:* $senθ < cosθ$ o $sen^3θ - cos^3θ<0$
#
#   $L'(θ)$ es decreciente en $(0, \frac{π}{4})$
#
#
# * Cuando $0<θ<\frac{π}{4}$:
#   Por ejemplo: $θ=1.39626$
#
#   $$sen(1.39626)=0.984$$
#
#   $$cos(1.39626)=0.173$$
#
#   *Por lo tanto:* $senθ > cosθ$ o $sen^3θ - cos^3θ>0$
#
#   $L'(θ)$ es creciente en $(\frac{π}{4}, \frac{π}{2})$
#
#
# **Por lo tanto** podemos decir que $θ=\frac{π}{4}$ en el intérvalo $(0, \frac{π}{2})$ produce un mínimo. → Con esto determinamos la varilla **más corta** que **NO** da vuelta por la esquina.
#
# $$L(\frac{π}{4}) = 6sec(\frac{π}{4}) + 6csc(\frac{π}{4})≈16.97 ft$$
#
# *Respuesta:* $16.97 ft$ es el lárgo máximo que puede tener una varilla para darle la vuelta alrededor de la esquina.

# %% [markdown]
# ###<font color= 9ACD32>4.
#
# ![image.png](data:image/png;base64,...)
#
#
#
# Se debe encontrar dos puntos $(x,y)$ para los cuales al trazar una linea desde $(0,2)$ (que es donde está el observador) sean la distancia más corta y la distancia más larga entre el observador y el objeto.
#
# *Objetivo:*
#
# $$d=\sqrt{(x_1 - x_2)^2+(y_1 - y_2)^2}$$
#
# Donde $y= h = \frac{-x^2}{100} + x + 100$
#
# *Reemplazamos:*
#
# $$d^2=(x_1 - 0)^2 + (y_1 -2)^2$$
#
# *Derivamos:*
#
# $$2dd'=2x + 2(y_1 - 2)y_1'$$
#
# $$y_1'= \frac{-x}{50} + 1$$
#
# *Igualamos a $0$:*
#
# $$2x + 2(\frac{-x^2}{100} + x + 98)(\frac{-x}{50} + 1) = 0$$
#
#
# **Análisis:**
#
# A partir de la ecuación anterior, podemos encontrar los posibles puntos críticos para determinar cuándo la distancia es máxima y cuando mínima.
#
# A la vez, haciendo un análisis gráfico en geogebra como lo muestra la imagen, podemos observar que la menor distancia entre el observador y el objeto es $98 ft$ y la distancia más larga es de $161.8 ft$ aproximadamente.
#
# *Por lo tanto,* la posición del objeto cuando está **más cerca** del observador es en el punto de corte con $y$, es decir en el punto $(0,100)$. Y la posición del objeto cuando está **más lejos** del observador es en punto de corte con $x$, es decir en el punto $(161.8 , 0)$

# %% [markdown]
# ##<font color= 9ACD32>Una aplicación: Coste Marginal
# El coste marginal es un concepto muy utilizado en microeconomía. Otra forma de describir el coste marginal es tomándolo como la variación que se produce en el coste total a la hora de aumentar en una unidad la producción.
#
# De estas dos ideas iniciales puede resumirse la definición en que el coste marginal es el coste al que se enfrenta una empresa en cuestión, en el momento de producir una unidad más de algo
#
# Se tiene entonces que:
#
# **El costo marginal**
#
# $$C_m(x)=\frac{dc}{dx}$$
#
# Ademas se tiene que:
#
# **Precio Marginal**
#
# $$P_m(x)=\frac{dP}{dx}$$
#
# **Utilidad marginal**
#
# $$U_m(x)=\frac{dU}{dx}$$
#
# Profundice en esta [Lectura](https://squareup.com/us/es/glossary/marginal-cost) sobre Microenomia y Coste Marginal.
#
# ###Ejercicio
#
# En la fabricación y venta de x unidades de cierto bien de consumo, las funciones de precio $P$ y de costo $C$ (en dólares) están dadas por:
#
# $$P(x) = 5.00 - 0.002x$$
#
# $$C(x)=3.00 + 1.10x$$
#
# Encuentre las expresiones para el ingreso, el costo y la utilidad marginales.
#  Determine el nivel de producción que producirá la máxima utilidad total.Explique con claridad cada proceso

# %% [markdown]
# ###<font color= 9ACD32>Desarrollo
#
# *Funciones base*
#
# * **Precio:**
# $$P(x) = 5.00 - 0.002x$$
#
# * **Costo:**
#
# $$C(x)=3.00 + 1.10x$$
#
#
# * **Ingresos:**
# $$I(x)= xP(x)= 5.00x - 0.002x^2$$
#
# * **Utilidad:**
# $$U(x)= I - C = (5x - 0.002x^2)-(3.00 + 1.10x)$$
#
# $$U(x)= -0.002x^2 + 3.9x -3$$
#
# **El costo marginal**
#
# $$C_m(x)=\frac{dc}{dx} = 1.10$$
#
# **El ingreso Marginal**
#
# $$I_m(x)=\frac{dI}{dx}= 5.00 - 0.004x$$
#
# **La utilidad marginal**
#
# $$U_m(x)=\frac{dU}{dx}= 3.9 - 0.004x$$
#
# **Máxima Utilidad**
#
# *Función objetivo*
#
# $$U_m(x)=\frac{dU}{dx}= 0$$
# $$3.9 - 0.004x=0$$
# $$3.9 = 0.004x$$
# $$975 = x$$
#
# → $975 > 0\:$ Punto máximo
#
# *Reemplazamos en la función original:*
#
# $$U(975) = -0.002(975)^2 + 3.9(975) -3$$
#
# $$U(975) ≈ $1898.25$$
#
# *Reemplazamos en las funciones costo marginal e ingreso marginal:*
#
# $$C_m(975)=\frac{dc}{dx} = 1.10$$
#
#
# $$I_m(975)=\frac{dI}{dx}= 5.00 - 0.004(975)=1.10$$
#
# **Respuesta:**
#
# El nivel de producción que producirá la máxima utilidad será en las sean $975$ unidades.
#
# La compañía tendrá un nivel de utilidad máxima cuando el costo de producir una una unidad extra sea el igual al ingreso de esa misma unidad.

# %% [markdown]
# ##<font color= 9ACD32>Una aplicación: Método de Newton
#
# Encontrar raíces de ciertos tipos de ecuaciones fue un problema que cautivó a
# los matemáticos durante siglos. Los ceros de una función polinomial f de grado 4 o menos (es decir, las raíces de la ecuación $f(x)$ siempre pueden encontrarse por medio de una fórmula algebraica que expresa la incógnita $x$ en términos de los coeficientes de $f$. Por ejemplo, la ecuación polinomial de grado 2 $ax^2+bx+c=0$ puede resolverse con la fórmula cuadrática:  $x=\frac{-b\pm \sqrt{b^2-4ac}}{2a}$.
#
# Uno de los logros más importantes en la historia de las matemáticas fue la demostración en el siglo XIX de que las ecuaciones polinomiales de grado mayor que 4 no pueden resolverse por medio de fórmulas algebraicas; en otras palabras, en términos de radicales.
#
# En esta sección consideraremos una técnica de aproximación que utiliza la derivada de una función $f$ o, con más precisión, una recta tangente a la gráfica de $f$. Este nuevo método se denomina **método de Newton**, o método de Newton-Raphson.
#
# Suponga que $f$ es diferenciable y suponga que $c$ representa alguna raíz
# real desconocida de $f(x)=0$. Sea $x_0$ un número que se escoge de manera arbitraria como primera conjetura para $c$, si $f(x_0) \neq 0$ se calcula $f'(x_0)$ y se contruye la tangente alrededor del punto $x_0$ y su ecuación sería
#
# $$y-f(x_0)=f'(x_0)(x-x_0)$$
#
# Entonces si $x=x_1$ y se despeja:
#
# $$x_1=x_0-\frac{f(x_0)}{f'(x_0)}$$
#
# si se repite el proceso, se tendría $x_2$:
#
# $$x_2=x_1-\frac{f(x_1)}{f'(x_1)}$$
#
# ...
#
# y asi sucesivamente hasta encontrar una raíz cercana, talque $|x_i-x_j|<ᵋ$
#
# Use esta [Lectura](https://estadistica-dma.ulpgc.es/FCC/05-3-Raices-de-Ecuaciones-2.html) para reforzar el método, ademas, se propone este [Video](https://youtu.be/n53t8CtaLrM) para su analisis.

# %%
#Analice el siguiente codigo. explique cada paso en el codigo anterior y compruebe

def newton(fun, der, x_n, epsilon=1e-6, steps=50):
    for n in range(steps + 1):
        # Evaluación de la función para ver si el resultado es válido
        f_x = fun(x_n)
        if abs(f_x) < epsilon:
            return x_n

        # Evaluación de la derivada
        d_f = der(x_n)
        if d_f == 0:
            print('Error la derivada es cero')
            return None

        # Estimación del siguiente punto
        x_n = x_n - f_x / d_f

        return None

# %%
import numpy as np
import matplotlib.pyplot as plt

#@title Hallar la raiz de cualquier funcion { run: "auto", vertical-output: true }
# proponga un código propio para calcular la raiz de cualquier función (use Cuestionario Colab):

def newton_raphson(f, fprime, x0, tol, maxiter):
    x = x0
    for i in range(maxiter):
        fx = f(x)
        if abs(fx) < tol:
            return x

        fp = fprime(x)
        if fp == 0:
            print('Error la derivada es cero')
            break
        x = x - fx / fp
    return x

# Ejemplo de uso:
function = lambda x: 2*(x**3) #@param {type:"raw"}
fprime = lambda x: 6*(x**2) #@param {type:"raw"}
x0 = -1 #@param {type:"number"}
tol = 1e-5
maxiter = 10000 #@param {type:"number"}
root = newton_raphson(function, fprime, x0, tol, maxiter)
print(f"La raíz de la función es: {root}")
# Out:
# La raíz de la función es: -0.011561019943888409

# %% [markdown]
# ##<font color= 9ACD32>Exercises

# %% [markdown]
# ###<font color= 9ACD32>I.
# For each of the following equations, use a graph to obtain initial guesses for solutions and then apply Newton’s method to locate the solutions within 0.0001. use code

# %% [markdown]
# ### 1.
# $ f(x)=x^5-6x^3+2x -2$

# %%
#1. Gráfica
import numpy as np
import matplotlib.pyplot as plt

# Deifnir las funciones
def f(x):
    return x ** 5 - 6 * x ** 3 + 2 * x - 2

def f_prime(x):
    return 5 * x ** 4 - 18 * x ** 2 + 2

x = np.arange(-2, 2, 0.1)

# Calcular los valores en y para f(x) y f'(x)
y = f(x)
y_prime = f_prime(x)


fig, ax = plt.subplots()

ax.plot(x, y, label='f(x) = x^5 - 6x^3 + 2x - 2')
ax.plot(x, y_prime, label="f'(x) = 5x^4 - 18x^2 + 2")

ax.set_title("Punto 1")
ax.set_xlabel("x")
ax.set_ylabel("f(x)")
plt.grid(color="grey", linestyle="--")
plt.axhline(0, color="black")
plt.axvline(0, color="black")
ax.legend()

plt.show()

# %%
# 1.
f1 = lambda x: x**5 - 6*(x**3) + 2*x - 2
f1_prime = lambda x: 5*(x**4) - 18*(x**2) + 2

print(f"Root: {newton_raphson(f1, f1_prime, -1, 0.0001, 10000)}")
# Out:
# Root: -0.9017702148742708

# %% [markdown]
# ### 2.
# $ f(x) = senx - x^2$

# %%
#2. Gráfica
import numpy as np
import matplotlib.pyplot as plt

# Deifnir las funciones
def f2(x):
    return np.sin(x) - x**2

def f2_prime(x):
    return np.cos(x) - 2*x

x = np.arange(-2, 2, 0.1)

# Calcular los valores en y para f(x) y f'(x)
y = f2(x)
y_prime = f2_prime(x)


fig, ax = plt.subplots()

ax.plot(x, y, label='f(x) = senx - x^2')
ax.plot(x, y_prime, label="f'(x) = cosx - 2x")

ax.set_title("Punto 2")
ax.set_xlabel("x")
ax.set_ylabel("f(x)")
plt.grid(color="grey", linestyle="--")
plt.axhline(0, color="black")
plt.axvline(0, color="black")
ax.legend()

plt.show()

# %%
#2.
#sinx - x^2=0
import math
def newton_raphson2(f, fprime, x0, tol, maxiter):
    x = x0
    for i in range(maxiter):
        fx = f(x)
        if abs(fx) < tol:
            return x

        fp = fprime(x)
        if fp == 0:
            print('Error la derivada es cero')
            break
        x = x - fx / fp
    return x

#Primera raiz
f = lambda x: math.sin(x) - x**2
fprime = lambda x: math.cos(x) - 2*x
x0 = 0
tol = 1e-5
maxiter = 10000
root = newton_raphson2(f, fprime, x0, tol, maxiter)
print(f"La primera raíz de la función es: {root}")

#segunda raiz
f = lambda x: math.sin(x) - x**2
fprime = lambda x: math.cos(x) - 2*x
x0 = 1
tol = 1e-5
maxiter = 10000
root = newton_raphson2(f, fprime, x0, tol, maxiter)
print(f"La segunda raíz de la función es: {root}")
# Out:
# La primera raíz de la función es: 0
# La segunda raíz de la función es: 0.8767262984818225

# %% [markdown]
# ### 3.
# $ f(t) = cost - t^2$

# %%
#3. Gráfica
import numpy as np
import matplotlib.pyplot as plt

# Deifnir las funciones
def f2(t):
    return np.cos(t) - t**2

def f2_prime(t):
    return -np.sin(t) - 2*t

t = np.arange(-2, 2, 0.1)

# Calcular los valores en y para f(x) y f'(x)
y = f2(t)
y_prime = f2_prime(t)


fig, ax = plt.subplots()

ax.plot(t, y, label='f(t) = cost - t^2')
ax.plot(t, y_prime, label="f'(t) = -sint - 2t")

ax.set_title("Punto 3")
ax.set_xlabel("t")
ax.set_ylabel("f(t)")
plt.grid(color="grey", linestyle="--")
plt.axhline(0, color="black")
plt.axvline(0, color="black")
ax.legend()

plt.show()

# %%
#3.
#cost - t^2=0
def newton_raphson3(f, fprime, x0, tol, maxiter):
    x = x0
    for i in range(maxiter):
        fx = f(x)
        if abs(fx) < tol:
            return x

        fp = fprime(x)
        if fp == 0:
            print('Error la derivada es cero')
            break
        x = x - fx / fp
    return x


f = lambda x: np.cos(x) - x**2
fprime = lambda x: -np.sin(x) - 2*x
x0 = 1
tol = 1e-5
maxiter = 10000
root = newton_raphson3(f, fprime, x0, tol, maxiter)
print(f"La raíz de la función es: {root}")

#segunda raiz
f = lambda x: np.cos(x) - x**2
fprime = lambda x: -np.sin(x) - 2*x
x0 = -1
tol = 1e-5
maxiter = 10000
root = newton_raphson(f, fprime, x0, tol, maxiter)
print(f"La segunda raíz de la función es: {root}")
# Out:
# La raíz de la función es: 0.8241323190509289
# La segunda raíz de la función es: -0.8241323190509289

# %% [markdown]
# ### 4.
# $ f(x)=2senx - \sqrt{x+1}$

# %%
#4. Gráfica
import numpy as np
import matplotlib.pyplot as plt

# Definir las funciones
def f(x):
    return 2 * np.sin(x) - np.sqrt(x + 1)

def f_prime(x):
    return 2 * np.cos(x) - (1 / (2 * np.sqrt(x + 1)))


x = np.arange(-5, 5, 0.1)

# Calcular los valores en y para f(x) y f'(x)
y = f(x)
y_prime = f_prime(x)


fig, ax = plt.subplots()


ax.plot(x, y, label='f(x) = 2sin(x) - sqrt(x+1)')
ax.plot(x, y_prime, label="f'(x) = 2cos(x) - (1/(2sqrt(x+1)))")

ax.set_title("Punto 4")
ax.set_xlabel("x")
ax.set_ylabel("y")
plt.grid(color="grey", linestyle="--")
plt.axhline(0, color="black")
plt.axvline(0, color="black")

ax.legend()
plt.show()
# Out:
# <ipython-input-25-379d131363a2>:6: RuntimeWarning: invalid value encountered in sqrt
#   return 2 * np.sin(x) - np.sqrt(x + 1)
# <ipython-input-25-379d131363a2>:9: RuntimeWarning: invalid value encountered in sqrt
#   return 2 * np.cos(x) - (1 / (2 * np.sqrt(x + 1)))

# %%
#4.
#2sinx - sqrt(x+1)
def newton_raphson4(f, fprime, x0, tol, maxiter):
    x = x0
    for i in range(maxiter):
        fx = f(x)
        if abs(fx) < tol:
            return x

        fp = fprime(x)
        if fp == 0:
            print('Error la derivada es cero')
            break
        x = x - fx / fp
    return x


f = lambda x: 2 * np.sin(x) - np.sqrt(x + 1)
fprime = lambda x: 2 * np.cos(x) - (1 / (2 * np.sqrt(x + 1)))
x0 = 1
tol = 1e-5
maxiter = 10000
root = newton_raphson4(f, fprime, x0, tol, maxiter)
print(f"La raíz de la función es: {root}")

f = lambda x: 2 * np.sin(x) - np.sqrt(x + 1)
fprime = lambda x: 2 * np.cos(x) - (1 / (2 * np.sqrt(x + 1)))
x0 = 2
tol = 1e-5
maxiter = 10000
root = newton_raphson4(f, fprime, x0, tol, maxiter)
print(f"La raíz de la función es: {root}")
# Out:
# La raíz de la función es: 0.7135295291215673
# La raíz de la función es: 2.073040414629217

# %% [markdown]
# ###<font color= 9ACD32>II.
#
# Use Newton’s method to approximate $\sqrt[3]{2}$ with an error less than 0.00005. Use $x^n-k=0$

# %%
def newton_raphmethod(f, fprime, x0, tol, maxiter):
    x = x0
    for i in range(maxiter):
        fx = f(x)
        if abs(fx) < tol:
            return x

        fp = fprime(x)
        if fp == 0:
            print('Error la derivada es cero')
            break
        x = x - fx / fp
    return x

f = lambda x: x**3 -2
fprime = lambda x: 3*x**2
x0 = 1
tol = 0.00005
maxiter = 10000
root = newton_raphmethod(f, fprime, x0, tol, maxiter)
print(f"La raíz de la función es: {root}")
# Out:
# La raíz de la función es: 1.2599210500177698

# %% [markdown]
# #<font color= 9ACD32>Gráficas
#
# Resumen del método:
#
#  Al graficar funciones no hay sustituto para el sentido común. Sin embargo, el procedimiento siguiente será útil en la mayoría de los casos.
#
# **Paso 1: Haga un análisis antes de utilizar cálculo**
#
# (a) Verifique el dominio y el rango de la función para ver si existen regiones en el plano que están excluidas.
#
# (b) Verifique la simetría con respecto al eje y y al origen. (¿La función es par o impar?)
#
# (c) Encuentre las intersecciones con los ejes de coordenadas.
#
# **Paso 2: Análisis con cálculo**
#
# (a) Utilice la primera derivada para encontrar los puntos críticos y determinar en dónde la gráfica es creciente y en dónde es decreciente.
#
# (b) Verifique los puntos críticos para saber si son máximos o mínimos locales.
#
# (c) Utilice la segunda derivada para determinar en dónde la gráfica es cóncava hacia arriba y en dónde es cóncava hacia abajo, y para localizar puntos de inflexión.
#
# (d) Encuentre las asíntotas.
#
# **Paso 3: Dibuje algunos puntos (incluya todos los puntos críticos y los puntos de inflexión)**.
#
# **Paso 4: Haga un bosquejo de la gráfica**.

# %% [markdown]
# ##<font color= 9ACD32>Ejercicios
#
# I. Haga un análisis como el sugerido en el resumen anterior y después elabore un bosquejo de la gráfica
#
#  1. $f(x)=\frac{x}{x+1}$
#
#  2. $g(x)=\frac{|x|+x}{2}(3x+2)$
#
#  3. $f(x)=\frac{x^2}{x^2-1}$
#
#  4. $h(x)=\frac{5.235x^3-1.245}{7.126x-3.141}$
#
# II. Trace el Bosquejo de una grafica que cumpla las siguientes condiciones:
#
# 1. $f$ es continua
#
# 2. $f$ es par
#
# 3. $f(0)=0$, $f(1)=2$
#
# 4. $f'(x)>0$ para $x>0$
#
# 5. $f''(x)>0$, para $x>0$
#
# III. Trace el Bosquejo de una grafica que cumpla las siguientes condiciones:
#
# a. $f$ es continua en todas partes
#
# b. $f(2)=-3$ y $f(6)=1$
#
# c. $f'(2)=0$ para $x\neq 2$
#
# d. $f'(6)=3$
#
# e. $f''(6)=0$; $f''(x)>0$ Para $2<x<6$
#
# f. $f''(x)<0$ Para $x>6$

# %% [markdown]
# ##<font color= 9ACD32>Respuestas</font>
#
# I.Haga un análisis como el sugerido en el resumen anterior y después elabore un bosquejo de la gráfica
#
#  1. $f(x)=\frac{x}{x+1}$
#
#
#  Dominio:($-∞,-1$) U ($-1,∞$)
#
#
#  Rango: ($-∞,1$) U ($1,∞$)
#
#  Simetria: Ninguna
#
#  Par: No es ni par ni impar
#
#  Intersecciones: (0,0)
#
#  Asintotas:
#
#   >-Asintota Vertical:  x = -1
#
#
#   >-Asintota Horizontal y = 1
#
#  Puntos criticos: No hay
#
#  Puntos de inflexion: No hay
#
#  ---
#
#  2. $g(x)=\frac{|x|+x}{2}(3x+2)$
#
#  Dominio: ($-∞,∞$)
#
#  Rango: (0,∞)
#
#  Simetria: Ninguna
#
#  Par: No es ni par ni impar
#
#  Intersecciones: (0,0)
#
#  Asintotas:
#    >-Asintota Vertical:  No hay
#
#
#   >-Asintota Horizontal y = 0
#
#  Puntos criticos: x = 0
#   > Minimo relativo: x = 0
#
#  Puntos de inflexion: No hay
#
#  ---
#
#  3. $f(x)=\frac{x^2}{x^2-1}$
#
#  Dominio: ($-∞,-1$) U (-1,1) U ($1,∞$)
#
#  Rango: (-∞,0) U (1,∞)
#
#  Simetria: Con el eje Y
#
#  Par: PAR
#
#  Intersecciones: (0,0)
#
#   Asintotas:
#     >-Asintota Vertical:  x = -1 y x = 1
#
#   >-Asintota Horizontal y = 1
#
#  Puntos criticos: x = 0
#
#  >Maximo relativo: x = 0
#
#  Puntos de inflexion: No hay
#
#  ---
#
#  4. $h(x)=\frac{5.235x^3-1.245}{7.126x-3.141}$
#
#  Dominio:Todos los reales menos ($\frac{3141}{7126}$)
#
#  Rango: Todos los reales (-∞,∞)
#
#  Simetria: No es simetrica
#
#  Par: No es ni par ni impar
#
#  Intersecciones:
#
#  En el eje Y (0,$\frac{415}{1047}$).
#
#  Con el eje X (0.61,0)
#
#   Asintotas:
#
#   >-Asintota Vertical:  x = $\frac{349}{792}$
#
#
#   >-Asintota Horizontal: No hay
#
#  Puntos criticos: x = -0.34
#  >Minimo relativo: x = -0.34
#
#  Puntos de inflexion: x= 0 y x = 0.44
#  >Concava hacia arriba : (-∞,0)
#
#  >Convexa: (0.44,∞)
#
#  ---
# ##<font color= 9ACD32>Bosquejo de las graficas</font>
#
# ###1-2.
# <img src="https://drive.google.com/uc?export=view&id=12Q7MS2FJVsEVKTt_g4l8ccdFA58NDhX7" width="300" height="300" align="justify" >
# <img src="https://drive.google.com/uc?export=view&id=1cVDyYPiwMUCR0VOrnozUO9KYBM7R5qTU" width="300" height="300" align="justify" >
#
#
# ###3-4.
# <img src="https://drive.google.com/uc?export=view&id=1HDYfxRBnbpnq7uI6CgsniJj8a1wJTvko" width="300" height="300" align="justify" >
# <img src="https://drive.google.com/uc?export=view&id=1EgiqKwQwlbenYFNzZdaz4oZqvdjB_p9Q" width="300" height="300" align="justify" >

# %% [markdown]
# ##II. Trace el Bosquejo de una grafica que cumpla las siguientes condiciones:
#
# 1. $f$ es continua
#
# 2. $f$ es par
#
# 3. $f(0)=0$, $f(1)=2$
#
# 4. $f'(x)>0$ para $x>0$
#
# 5. $f''(x)>0$, para $x>0$
#
# ###Funcion:
#
# $$f(x) = 2x^2$$
# $$f'(x) = 4x$$
# $$f''(x) = 4$$
#
# ###Grafica:
#
# <img src="https://drive.google.com/uc?export=view&id=1q9rKG3Lu3_4yELjO2ImTAAacnw1S_p0T" width="500" height="500" align="justify" >

# %% [markdown]
# ---
# ##III. Trace el Bosquejo de una grafica que cumpla las siguientes condiciones:
#
# a. $f$ es continua en todas partes
#
# b. $f(2)=-3$ y $f(6)=1$
#
# c. $f'(2)=0$
#
# d. $f'(6)=3$
#
# e. $f''(6)=0$; $f''(x)>0$ Para $2<x<6$
#
# f. $f''(x)<0$ Para $x>6$
#
# <img src="https://drive.google.com/uc?export=view&id=1598pOg9k6-N0j1rTtoAS701zCvGUHhPi" width="500" height="500" align="justify" >
